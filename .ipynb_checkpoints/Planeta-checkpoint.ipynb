# %%
#introducir una clase estrella
class Planeta:
    def __init__(self, anfitriona, nombre, masa, radio):
        self.nombre = nombre
        self.masa = masa
        self.radio = radio
        self._anfitriona = anfitriona

    def luminosidad(self):
        return self._anfitriona.calcular_luminosidad_total()

    def luminosidad_sec_principal(self):
        return self._anfitriona.calcular_luminosidad_secuencia_principal()

    def period_rot_kepler(self):
        # Define this method based on your needs
        pass

    def metodo_descubrimiento(self):
        # Define this method based on your needs
        pass

    def tatooine(self):
        # Define this method based on your needs
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 45>()
#      42     print("Luminosidad en la secuencia principal de la estrella anfitriona:", planeta.luminosidad_sec_principal())
#      44 # Ejecutamos el ejemplo
# ---> 45 ejemplo_uso_planeta()
#
# Input In [1], in ejemplo_uso_planeta()
#      26 def ejemplo_uso_planeta():
#      27     # Creamos una estrella como anfitriona del planeta
# ---> 28     estrella = Estrella("Sol", 1.989e30, 6.957e8)
#      30     # Creamos un planeta orbitando la estrella
#      31     planeta = Planeta(estrella, "Tierra", 5.972e24, 6.371e6)
#
# NameError: name 'Estrella' is not defined
